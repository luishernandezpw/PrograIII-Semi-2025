# %% [markdown]
# <a href="https://colab.research.google.com/github/luishernandezpw/PrograIII-Semi-2025/blob/librerias/uso_librerias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
ruta = "/content/notas.csv"
notas = pd.read_csv(ruta, sep=";", encoding="utf-8")

# %%
print(notas)
# Out:
#    alumno  nota
# 0    Luis     5
# 1    Juan     8
# 2   Maria     9
# 3    Jose    10
# 4   Oscar     4
# 5   Pedro     5
# 6   Ramon     7
# 7  Carmen     5

# %%
print( notas["alumno"][0] )
# Out:
# Luis

# %%
#saca el listado de los alumnos aprobados
aprobados  = notas[ notas["nota"]>=6 ]
print(aprobados)
# Out:
#   alumno  nota
# 1   Juan     8
# 2  Maria     9
# 3   Jose    10
# 6  Ramon     7

# %%
#sacar el listado de los alumnos reprobados
reprobados = notas[ notas["nota"]<6 ]
print(reprobados)
# Out:
#    alumno  nota
# 0    Luis     5
# 4   Oscar     4
# 5   Pedro     5
# 7  Carmen     5

# %%
print("Cantidad de Alumnos aprobados", len(aprobados))

cantidad_aprobados = notas.loc[ notas["nota"]>=6 ].agg({"count"})
print(cantidad_aprobados)
# Out:
# Cantidad de Alumnos aprobados 4
#        alumno  nota
# count       4     4

# %%
print("Cantidad de Alumnos reprobados", len(reprobados))

cantidad_reprobados = notas.loc[ notas["nota"]<6 ].agg({"count"})
print(cantidad_reprobados)
# Out:
# Cantidad de Alumnos reprobados 4
#        alumno  nota
# count       4     4

# %%
grupo_notas = notas.groupby(["nota"]).agg({
    'alumno': lambda n: ', '.join( map(str,n) )
})
print(grupo_notas)
# Out:
#                    alumno
# nota
# 4                   Oscar
# 5     Luis, Pedro, Carmen
# 7                   Ramon
# 8                    Juan
# 9                   Maria
# 10                   Jose

# %%
#importar las librerias para graficas
import matplotlib.pyplot as plt
import seaborn as sns

# %%
notas['estado'] = notas['nota'].apply(lambda n: 'Aprobado' if n >= 6 else 'Reprobado')

# %%
sns.set(style="whitegrid")
sns.countplot(data=notas, x='estado', palette={'Aprobado': 'green', 'Reprobado': 'red'})
plt.title('Alumnos aprobados y reprobados')
plt.xlabel('Estado')
plt.ylabel('Cantidad de alumnos')
plt.show()
# Out:
# /tmp/ipython-input-1800193188.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=notas, x='estado', palette={'Aprobado': 'green', 'Reprobado': 'red'})

# %% [markdown]
# **EJERCICIO:** En python Realizar la clasficicacion de edades de los alumnos cuantos son mayores de edad y cuantos son menores de edad.

# %% [markdown]
# **Enternar una IA con la libreria de tensorflow que convierta gradis celsius a farenheits**

# %%
#importar las librerias necesarias
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
#leer el archivo de las temperaturas para el entrenamiento
grados = pd.read_csv("/content/grados.csv", sep=";", encoding="utf-8")
print(grados, grados["f"])
# Out:
#       c      f
# 0   -40  -40.0
# 1   -35  -31.0
# 2   -30  -22.0
# 3   -25  -13.0
# 4   -20   -4.0
# 5   -15    5.0
# 6   -10   14.0
# 7    -8   17.6
# 8    -5   23.0
# 9    -2   28.4
# 10    0   32.0
# 11    1   33.8
# 12    3   37.4
# 13    5   41.0
# 14   10   50.0
# 15   12   53.6
# 16   14   57.2
# 17   16   60.8
# 18   18   64.4
# 19   20   68.0
# 20   22   71.6
# 21   24   75.2
# 22   26   78.8
# 23   30   86.0
# 24   35   95.0
# 25   40  104.0
# 26   45  113.0
# 27   50  122.0
# 28   60  140.0
# 29  100  212.0 0     -40.0
# 1     -31.0
# 2     -22.0
# 3     -13.0
# 4      -4.0
# 5       5.0
# 6      14.0
# 7      17.6
# 8      23.0
# 9      28.4
# 10     32.0
# 11     33.8
# 12     37.4
# 13     41.0
# 14     50.0
# 15     53.6
# 16     57.2
# 17     60.8
# 18     64.4
# 19     68.0
# 20     71.6
# 21     75.2
# 22     78.8
# 23     86.0
# 24     95.0
# 25    104.0
# 26    113.0
# 27    122.0
# 28    140.0
# 29    212.0
# Name: f, dtype: float64

# %%
c = grados["c"]
f = grados["f"]

print(c,f)
# Out:
# 0     -40
# 1     -35
# 2     -30
# 3     -25
# 4     -20
# 5     -15
# 6     -10
# 7      -8
# 8      -5
# 9      -2
# 10      0
# 11      1
# 12      3
# 13      5
# 14     10
# 15     12
# 16     14
# 17     16
# 18     18
# 19     20
# 20     22
# 21     24
# 22     26
# 23     30
# 24     35
# 25     40
# 26     45
# 27     50
# 28     60
# 29    100
# Name: c, dtype: int64 0     -40.0
# 1     -31.0
# 2     -22.0
# 3     -13.0
# 4      -4.0
# 5       5.0
# 6      14.0
# 7      17.6
# 8      23.0
# 9      28.4
# 10     32.0
# 11     33.8
# 12     37.4
# 13     41.0
# 14     50.0
# 15     53.6
# 16     57.2
# 17     60.8
# 18     64.4
# 19     68.0
# 20     71.6
# 21     75.2
# 22     78.8
# 23     86.0
# 24     95.0
# 25    104.0
# 26    113.0
# 27    122.0
# 28    140.0
# 29    212.0
# Name: f, dtype: float64

# %%
#modelo
modelo = tf.keras.Sequential()
modelo.add(tf.keras.layers.Dense(units=1, input_shape=[1]))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#compilar el modelo
modelo.compile(optimizer=tf.keras.optimizers.Adam(1.0), loss='mean_squared_error')

# %%
#entrenar el modelo
epocas = modelo.fit(c, f, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step - loss: 6506.7861
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2672.7104
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 936.6592
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 932.0596
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1740.0227
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2335.6165
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 2318.9607
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1841.6779
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1218.7587
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 720.1506
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 493.8246
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 543.2951
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 750.3566
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 948.3360
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1012.8931
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 912.6649
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 699.7605
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 465.9884
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 295.8837
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 233.2141
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 268.5277
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 350.5882
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 416.0890
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 421.6660
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 361.0323
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 261.1097
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 163.5586
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 103.0462
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 92.0775
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 118.1003
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 153.0964
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 169.8151
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 155.4554
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 115.8598
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 69.4963
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 35.9683
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 25.6690
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 35.6413
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 53.0500
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 63.5412
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 59.2918
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 42.2773
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 21.6075
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 7.2938
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 4.4319
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 11.0065
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 20.0993
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 24.6527
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 21.6322
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 13.1789
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 4.4913
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1847
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.5506
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 6.2623
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 10.3720
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 11.0298
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 8.1013
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 3.8105
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.9259
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.8740
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 3.0151
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 5.3897
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 6.2258
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 5.0911
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 2.9641
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.3394
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.1204
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 2.0923
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 3.2523
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 3.6387
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 3.0006
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 1.8590
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 1.0084
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 0.9016
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 1.3790
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 1.8865
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.9471
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 1.4999
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.8764
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.4882
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.5042
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.7643
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.9559
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.8786
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.5794
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2748
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1532
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2323
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.3736
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.4182
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.3164
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1484
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0376
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0428
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1215
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1811
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1634
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0864
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0162
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0029
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0416
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0854
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0923
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0598
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0201
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0062
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0236
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0496
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0584
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0438
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0214
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0109
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0180
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0316
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0369
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0291
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0161
# Epoch 118/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0090
# Epoch 119/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0118
# Epoch 120/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0186
# Epoch 121/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0210
# Epoch 122/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0162
# Epoch 123/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0087
# Epoch 124/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0046
# Epoch 125/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0060
# Epoch 126/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0095
# Epoch 127/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0104
# Epoch 128/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0074
# Epoch 129/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0033
# Epoch 130/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0014
# Epoch 131/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0025
# Epoch 132/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0044
# Epoch 133/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0047
# Epoch 134/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0029
# Epoch 135/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 7.7411e-04
# Epoch 136/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.7893e-04
# Epoch 137/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0011
# Epoch 138/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0022
# Epoch 139/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0021
# Epoch 140/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0011
# Epoch 141/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.4742e-04
# Epoch 142/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.4759e-04
# Epoch 143/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 8.4630e-04
# Epoch 144/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0014
# Epoch 145/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0012
# Epoch 146/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 5.3625e-04
# Epoch 147/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 1.6498e-04
# Epoch 148/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 3.4290e-04
# Epoch 149/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 7.5782e-04
# Epoch 150/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 9.1256e-04
# Epoch 151/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 6.6601e-04
# Epoch 152/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 3.1452e-04
# Epoch 153/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.0795e-04
# Epoch 154/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.7906e-04
# Epoch 155/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 5.6599e-04
# Epoch 156/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 5.3737e-04
# Epoch 157/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.2870e-04
# Epoch 158/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.5828e-04
# Epoch 159/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.6521e-04
# Epoch 160/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 2.7764e-04
# Epoch 161/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 3.2676e-04
# Epoch 162/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2.4308e-04
# Epoch 163/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1.1298e-04
# Epoch 164/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 5.8860e-05
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.0178e-04
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.5716e-04
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.4444e-04
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 7.3653e-05
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.7983e-05
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2.2875e-05
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 6.1486e-05
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 7.6643e-05
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 4.8892e-05
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.0702e-05
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.4056e-06
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 2.2178e-05
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 4.1420e-05
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 3.5675e-05
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.4114e-05
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.3267e-06
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1.0519e-05
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.4805e-05
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2.7074e-05
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.6168e-05
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 6.0847e-06
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 7.3075e-06
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.5542e-05
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.9173e-05
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.3988e-05
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 6.6115e-06
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 4.9491e-06
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 8.8719e-06
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.1805e-05
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 9.5366e-06
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 4.7124e-06
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.5150e-06
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 4.1603e-06
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 6.1930e-06
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 5.4153e-06
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2.5819e-06

# %%
#prediccion
g = int(input("Celsius: "))
resp = modelo.predict(np.array([g]))
print("Farenheits: ", resp[0][0])
# Out:
# Celsius: 121
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Farenheits:  249.8008

# %%
#guardar el modelo
modelo.save("grados.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
#Entrenar una IA con la libreria de tensorflow que convierta grados celsius a kelvin.
#el archivo se debe de llamar kelvin.csv

# %% [markdown]
# **TAREA: **
# 1. Entrenar de la IA para convertir Celsius a Farenheit y a Kelvin
# 2. Exportar (guardar) el modelo
# 3. Cargar el modelo de IA en Python Nativo
# 4. Crear la API para hacer llamadas y convertir
# 5. Crear la pagina web con HTML, bootstrap y JavaScript para convertir grados celsius a Farenheit y a Kelvin
